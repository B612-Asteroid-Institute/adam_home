# %%
print ("hello world")
# Out:
# hello world

# %% [markdown]
# Here is an example of text and an equation in a "markdown cell"
#
# The is done with MathJax:
#
# \begin{align}
#  \dot{x} & = \sigma(y-x) \\
#  \dot{y} & = \rho x - y - xz \\
#  \dot{z} & = -\beta z + xy
# \end{align}
#
# And also:
#
# \begin{equation*}
# \mathbf{V}_1 \times \mathbf{V}_2 =  \begin{vmatrix}
# \mathbf{i} & \mathbf{j} & \mathbf{k} \\
# \frac{\partial X}{\partial u} &  \frac{\partial Y}{\partial u} & 0 \\
# \frac{\partial X}{\partial v} &  \frac{\partial Y}{\partial v} & 0
# \end{vmatrix}
# \end{equation*}

# %% [markdown]
# Here is some code for importing Python modules

# %%
import numpy as np

import pandas as pd

import scipy as sp

import matplotlib

import matplotlib.pyplot as plt

# %% [markdown]
# Here is an example of a simple graph:

# %%
plt.plot([1,2,3,4])
plt.ylabel('some numbers')
plt.show()

# %% [markdown]
# Another example of graphing:

# %%
# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %% [markdown]
# Now, to control STK:

# %%
import os

import win32com.client as win32

import datetime

# %%
#stk_app = win32.gencache.EnsureDispatch('STK11.Application')
stk_app = win32.dynamic.Dispatch('STK11.Application')

STK = stk_app.Personality

root = stk_app.Personality

stk_app.Visible = True

# %% [markdown]
# Stop at this point, create a new scenario, and a saetllite named "Satellite1", and change it to be an Astrogator Satellite.
# And run THe satellite.

# %%
g_gatorDefn = STK.scenario(0).Satellite("Satellite1").GetAstrogatorDefn()

initState = g_gatorDefn.GetSegmentByName("Initial_State")
mnvr = g_gatorDefn.GetSegmentByName("Maneuver")

# %%
period = initState.GetResultValue("Orbit_Period").Getin("hr")

# %%
print(period)
# Out:
# 1.5086603159229386

# %% [markdown]
# And that's all!

# %%
initState.InitialState.Cartesian.X.value
# Out:
# 100000.0

# %%
initState.InitialState.Cartesian.X.value = 98765

# %%
initState.InitialState.Cartesian.X.value
# Out:
# 100.0

# %%
mnvr.ImpulsiveMnvr.Cartesian.X.value = 987.654

# %%
mnvr.ImpulsiveMnvr.Cartesian.X.Set(345.876,"m/sec")
# Out:
# <COMObject <unknown>>
